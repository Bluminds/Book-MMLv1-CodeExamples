# %% [markdown]
# # Capítulo 1: Introducción a la Matemática para Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ### 1.1

# %% [markdown]
# ---

# %% [markdown]
# ### 1.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.6.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.7.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.8.

# %% [markdown]
# ---

# %% [markdown]
# ### 1.9.

# %% [markdown]
# ---

# %% [markdown]
# # FIN DEL CAPÍTULO
