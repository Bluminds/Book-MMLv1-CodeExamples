# %% [markdown]
# # Capítulo 10: Algoritmos No Supervisados en Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ### 10.1

# %% [markdown]
# ---

# %% [markdown]
# ### 10.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.6.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.7.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.8.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.9.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.10.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.11.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.12.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.13.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.14.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.15.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.16.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.17.

# %% [markdown]
# ---

# %% [markdown]
# ### 10.18.

# %% [markdown]
# # FIN DEL CAPÍTULO
