# %% [markdown]
# # Capítulo 9: Algoritmos Supervisados en Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ### 9.1

# %% [markdown]
# ---

# %% [markdown]
# ### 9.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.6.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.7.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.8.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.9.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.10.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.11.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.12.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.13.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.14.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.15.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.16.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.17.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.18.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.19.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.20.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.21.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.22.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.23.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.24.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.25.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.26.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.27.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.28.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.29.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.30.

# %% [markdown]
# ---

# %% [markdown]
# ### 9.31.

# %% [markdown]
# # FIN DEL CAPÍTULO
