# %% [markdown]
# # Capítulo 5: Aritmética, Algebra, Geometría y Trigonometría

# %% [markdown]
# ---

# %% [markdown]
# ### 5.1

# %% [markdown]
# ---

# %% [markdown]
# ### 5.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.6.

# %% [markdown]
# # FIN DEL CAPÍTULO
