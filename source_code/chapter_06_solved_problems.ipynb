# %% [markdown]
# # Capítulo 6: Algebra Lineal, Cálculo y Ecuaciones Diferenciales

# %% [markdown]
# ---

# %% [markdown]
# ### 6.1

# %% [markdown]
# ---

# %% [markdown]
# ### 6.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 6.6.

# %% [markdown]
# ---

# %% [markdown]
# # FIN DEL CAPÍTULO
