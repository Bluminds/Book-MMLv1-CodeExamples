# %% [markdown]
# # Capítulo 4: Visualizaciones para Machine Learning

# %% [markdown]
# ---

# %% [markdown]
# ### 4.1

# %% [markdown]
# ---

# %% [markdown]
# ### 4.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.6.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.7.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.8.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.9.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.10.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.11.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.12.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.13.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.14.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.15.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.16.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.17.

# %% [markdown]
# ---

# %% [markdown]
# ### 4.18.

# %% [markdown]
# # FIN DEL CAPÍTULO
