# %% [markdown]
# # Capítulo 7: Probabilidad y Estadística

# %% [markdown]
# ---

# %% [markdown]
# ### 7.1

# %% [markdown]
# ---

# %% [markdown]
# ### 7.2.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.3.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.4.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.5.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.6.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.7.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.8.

# %% [markdown]
# ---

# %% [markdown]
# ### 7.9.

# %% [markdown]
# # FIN DEL CAPÍTULO
